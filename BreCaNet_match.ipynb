# %% [markdown]
# This notebook is about matching the clinical data (so the IHC results) to the patients
#
# Pathway to match the data:
#
# folderIDs ==> 7th col File_metadata.txt ==> 9th col File_metadata.txt ==>

# %%
# packages

import gzip
import numpy as np
import os
import shutil

# %%
# paths to match patient biospecimen data

IDPath = '/Users/ursulawidocki/Desktop/BreCaNet/Data/IDList.txt'
folderIDPath = '/Users/ursulawidocki/Desktop/BreCaNet/Data/foldIDList.txt'

indivList = list() # codes of the patients' expression file
folderIDs = list() # codes of the patient IDs on the folder

with open(IDPath, "r") as file:
    for line in file.readlines():
        indivList.append(line[0:-1])

with open(folderIDPath, "r") as file:
    for line in file.readlines():
        folderIDs.append(line[0:-1])

#print(len(folderIDs))
#print(folderIDs)

# %%
manifestPath = '/Users/ursulawidocki/Desktop/BreCaNet/Data/gdc_manifest_20191011_142215.txt'
clinicalPath = '/Users/ursulawidocki/Desktop/BreCaNet/Data/clinicalFiles/8162d394-8b64-4da2-9f5b-d164c54b9608/nationwidechildrens.org_clinical_patient_brca.txt'

# %%
# reads File_metadata.txt

metaPath = '/Users/ursulawidocki/Desktop/BreCaNet/Data/File_metadata.txt'

barcode = ["" for x in range(len(folderIDs))] # barcodes and indivList align by index


with open(metaPath, "r") as metaFile:
    next(metaFile) # skips first line
    for line in metaFile.readlines():
        #print(line.strip().split("\t")[7])
            
        if line.strip().split("\t")[7] in folderIDs:
            
            ind = folderIDs.index(line.strip().split("\t")[7])
            barcode[ind]= line.strip().split("\t")[9]
            
print(len(barcode))   
#print(barcodeList)
# Out:
# 832

# %%
# reads the clinical data
# uses barcodeList to get the patient IHC status

# col 43 ER IHC status
# col 49 PR IHC status
# col 55 HER2 IHC status

clinicCol0 = list()
clinicCol1 = list()

clinicMatrix = np.zeros((len(indivList), 3))

with open(clinicalPath, "r") as clinicFile:
    #next(clinicFile)
    #next(clinicFile)
    #next(clinicFile)
    for line in clinicFile.readlines():
        print(line.strip().split("\t")[46])
        #IDstring = line.strip().split("\t")[0].lower()
        #barcode = line.strip().split("\t")[1]
        
        
        
        
        #clinicCol0.append(IDstring)
        #clinicCol1.append(barcode)
        
        #if clinicCol1 in barcodeList
         #get barcodeList index
         #
        
#print(len(clinicCol0)) # 1097
#print(len(clinicCol1)) # 1097
# Out:
# er_ihc_score
# immunohistochemistry_positive_cell_score
# CDE_ID:2230166
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# 2+
# [Not Available]
# [Not Available]
# 2+
# [Not Available]
# [Not Available]
# 3+
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# 2+
# [Not Available]
# 0
# 2+
# [Not Available]
# [Not Available]
# 1+
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# 0
# [Not Available]
# 0
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# 3+
# 0
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# 3+
# 3+
# [Not Available]
# 3+
# 2+
# [Not Available]
# [Not Available]
# [Not Available]
# 3+
# 3+
# 3+
# 3+
# 1+
# 3+
# 3+
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# 3+
# 3+
# [Not Available]
# 3+
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# 3+
# [Not Available]
# [Not Available]
# [Not Available]
# 3+
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# 1+
# 2+
# [Not Available]
# [Not Available]
# [Not Available]
# 3+
# 3+
# 1+
# 2+
# 3+
# 1+
# 2+
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
# [Not Available]
